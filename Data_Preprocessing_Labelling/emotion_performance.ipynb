# %% [markdown]
# # 3. Evaluating the Performance of the Emotion Labels

# %%
from google.colab import drive

# Mounting Google Drive
drive.mount('/content/drive', force_remount=True) # Adding force_remount=True to force the remounting process
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
train_df = pd.read_csv('/content/drive/MyDrive/train_data.csv')
train_df["emotion_label"].unique()
"mrm8488/t5-base-finetuned-emotion"
# Out:
# array(['admiration', 'neutral', 'approval', 'gratitude', 'realization',
#        'confusion', 'excitement', 'disappointment', 'curiosity',
#        'disapproval', 'love', 'optimism', 'joy', 'annoyance', 'desire',
#        'nervousness', 'caring', 'surprise', 'amusement', 'sadness',
#        'remorse', 'pride', 'embarrassment', 'disgust', 'anger', 'fear',
#        'relief'], dtype=object)

# %%
import pandas as pd
train_df = pd.read_csv('/content/drive/MyDrive/train_data.csv')
train_df[["reviews","emotion_label"]].iloc[:100]
# Out:
#                                               reviews   emotion_label
# 0   Andrew Ng has provided a fantastic resource fo...      admiration
# 1   Peer graded assingments take a lot of time bec...         neutral
# 2   This course was the first actual course for Pr...      admiration
# 3   The best course to start with if you are enter...        approval
# 4   I wanted to learn more about Functional Progra...        approval
# ..                                                ...             ...
# 95  The Course cleared all of my doubts regarding ...     realization
# 96  Very unsatisfied. At the end, I feel I learnt ...  disappointment
# 97  A very clear, well structured course for learn...        approval
# 98  Great course, though was a bit difficult for m...      admiration
# 99   I learnt a lot! I loved the programming chall...     realization
#
# [100 rows x 2 columns]

# %% [markdown]
# For 100 data entries, the accuracy rate by manual inspection is 88%, where most of the misclassification occurs between the approval and admiration emotion. For every instance that's labelled with "admiration", a label of "enjoyment/happiness" would be more appropriate.
